# %% [markdown]
# #Task1: Document the Notebook Using mark down %md

# %% [markdown]
# ##Notebook Documentation

# %% [markdown]
# ### MARK DOWN

# %%
# %python
from IPython.display import display, HTML
display(HTML('<span style="color:red; font-weight:bold;">Sunil Asha</span>'))

# %% [markdown]
# ![](https://fpimages.withfloats.com/actual/6929d1ac956d0a744b5c9822.jpeg) <br>

# %% [markdown]
# #Task2: Create a volume namely usage_metrics using sql magic command %sql

# %%
# %sql
CREATE VOLUME IF NOT EXISTS workspace.default.usage_metrics;

# %% [markdown]
# #Task3:Call the notebook 4_child_nb_dataload using the magic command %run

# %%
# %run "/Workspace/Users/sunilasha625@gmail.com/DataBricksCodeRepo/MAGIC_COMMAND_Practice/4_child_nb_dataload"

# %% [markdown]
# #Task5: list the file is created in the given volume or not and do the head of this file using fs magic command %fs

# %%
# %fs
ls /Volumes/workspace/default/usage_metrics/

# %%
# %fs 
head /Volumes/workspace/default/usage_metrics/mobile_os_usage.csv

# %% [markdown]
# #Task6: Create a pyspark dataframe df1 reading the data from the above file using pyspark magic command %python

# %%
# %python
df1=spark.read.csv("/Volumes/workspace/default/usage_metrics/mobile_os_usage.csv")
df1.show(5)

# %% [markdown]
# #Task7: Write the above dataframe df1 data into a databricks table called 'default.mobile_os_usage' using pyspark magic command %python

# %%
df1.write.saveAsTable("mobile_os_usage")

# %% [markdown]
# #Task8: Write sql query to display the data loaded into the table 'default.mobile_os_usage' using the pyspark magic command %python

# %%
# %python
spark.read.table("mobile_os_usage").show(2)

# %% [markdown]
# #Task9: Create a python function to convert the given input to upper case

# %%
def to_upper(text):
    return text.upper()
result=to_upper("sunil")
print(result)

# %%
result = to_upper("hello databricks")
print(result)

# %% [markdown]
# #Task10: Install pandas library using the pip python magic command %pip

# %%
# %pip install pandas

# %% [markdown]
# #Task11: Import pandas, using pandas read_csv and display the output using the magic command %python

# %%
# %python

import pandas as pd

# Path of the file stored in the Volume
file_path = "/Volumes/workspace/default/usage_metrics/mobile_os_usage.csv"

# Read the CSV file using pandas
df_pd = pd.read_csv(file_path)

# Display the DataFrame
df_pd.head()

# %% [markdown]
# #Task12: echo "Magic commands tasks completed" using the linux shell magic command %sh

# %%
# %sh
echo "Magic commands tasks completed"
