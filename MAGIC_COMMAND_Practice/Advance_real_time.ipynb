# %%
# %sql

CREATE TABLE sales_demo (
    sale_id INT,
    product STRING,
    quantity INT,
    price DOUBLE,
    sale_date DATE
);

INSERT INTO sales_demo VALUES
(1, 'Laptop', 2, 55000, '2025-01-01'),
(2, 'Mouse', 5, 500, '2025-01-02'),
(3, 'Keyboard', 3, 1200, '2025-01-03'),
(4, 'Laptop', 1, 56000, '2025-01-03'),
(5, 'Mouse', 4, 450, '2025-01-04');
