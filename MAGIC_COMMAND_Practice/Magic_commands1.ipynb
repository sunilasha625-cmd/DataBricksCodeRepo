# %% [markdown]
# #COMPLETE MAGIC COMMANDS NOTEBOOK EXAMPLE
# Let us understand about creating notebooks & magical commands
# ![](https://s.yimg.com/fz/api/res/1.2/UwQDLJVZiPNd41YdZKy9Pg--~C/YXBwaWQ9c3JjaGRkO2ZpPWZpbGw7aD00MTI7cHhvZmY9NTA7cHlvZmY9MTAwO3E9ODA7c3M9MTt3PTM4OA--/https://i.pinimg.com/736x/07/21/1d/07211d2613d7d8c03646943718178c93.jpg)

# %% [markdown]
# ##Let us learn first about Magical Commands
# **Important Magic Commands**
# - %md: allows you to write markdown text to design the notebook.
# - %run: runs a Python file or a notebook.
# - %sh: executes shell commands on the cluster nodes.
# - %fs: allows you to interact with the Databricks file system.
# - %sql: allows you to run Spark SQL/HQL queries.
# - %python: switches the notebook context to Python.
# - %pip: allows you to install Python packages.
#
# **Not Important Magic Commands or We learn few of these where we have Cloud(Azure) dependency**
# - %scala: switches the notebook context to Scala.
# - %r: switches the notebook context to R.
# - %lsmagic: lists all the available magic commands.
# - %config: allows you to set configuration options for the notebook.
# - %load: loads the contents of a file into a cell.
# - %who: lists all the variables in the current scope.

# %% [markdown]
# ####How to call a notebook from the current notebook using %run magic command

# %%
# %run "/Workspace/Users/sunilasha625@gmail.com/MAGIC_COMMAND_Practice/Magic_command_child"

# %% [markdown]
# ####How to run a linux commands inside a notebook using %sh magic command

# %%
# %sh
ls

# %% [markdown]
# We are going to use Databricks Unity Catalog (We don't know about it yet)
# to create tables and files under the volume (catalog/schema/volume/folder/files)
# - workspace(Your catalog)
# - default(Your (default) schema)
# - mymanagedtable(Name of your volume (folder))

# %%
# %sql
CREATE VOLUME IF NOT EXISTS workspace.default.mymanagedtable

# %% [markdown]
# ####Upload some sample data going into (Catalog -> My Organization -> Workspace -> Default -> Volumes), How to run a DBFS (Hadoop) FS commands inside a notebook using %fs magic command to copy the uploaded data into some other volume from the uploaded volume

# %%
# %fs
ls /Volumes/workspace/default/mymanagedtable

# %%
# %sql
CREATE VOLUME IF NOT EXISTS workspace.default.vol

# %% [markdown]
# ####Upload some sample data going into (Catalog -> My Organization -> Workspace -> Default -> Volumes), How to run a DBFS (Hadoop) FS commands inside a notebook using %fs magic command to copy the uploaded data into some other volume from the uploaded volume

# %%
# %fs
cp "/Volumes/workspace/default/mymanagedtable/employees.csv" "/Volumes/workspace/default/vol/employees.csv"

# %% [markdown]
# Rather using fs command, we can use databricks utility command (comprehensive) to copy the data/any other filesystem operations in the DBFS

# %%
dbutils.fs.cp(
    "dbfs:/Volumes/workspace/default/mymanagedtable/employees.csv", "/Volumes/workspace/default/vol/employees.csv")

# %% [markdown]
# ####How to run a Spark SQL/HQL Queries inside a notebook using %sql magic command

# %%
# %sql
create table if not exists cities1(id int,city string);
insert into cities1 values(3,'Mumbai'),(4,'Lucknow');
select * from cities1;

# %%
# %sql
update cities1 set city='Kolkata' where id=4;

# %%
# %sql
from cities1 select *;

# %% [markdown]
# ####How to run a Python Program inside a notebook using %python  magic command or by default the cell will be enabled with python interpretter only

# %%
# %python
def sqrt(a):
    return a*a
print("square root function call ",sqrt(10))

# %%
# %python
print("square root function call ",sqrt(10))

# %%
# %python 
df1=spark.read.csv("/Volumes/workspace/default/mymanagedtable/employees.csv",header=True)
print(df1.is_cached)
df2=df1.repartition(4)
display(df2)

# %%
# %python
df2.write.saveAsTable("healthcare_patients")

# %%
# %python
spark.read.table("healthcare_patients").show(2)
