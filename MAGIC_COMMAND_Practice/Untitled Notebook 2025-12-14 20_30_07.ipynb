# %%
content = """id,name,age
1,Sunil,30
2,Asha,28
"""
dbutils.fs.put(
    "/Volumes/workspace/default/sales_project/sample.csv",
    content,
    overwrite=True
)
dbutils.fs.head("/Volumes/workspace/default/sales_project/sample.csv")

dff1=spark.read.option("header",True).csv("/Volumes/workspace/default/sales_project/sample.csv")
dff1.display()
