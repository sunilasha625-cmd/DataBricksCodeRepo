# %% [markdown]
# #Task3:

# %%
# %py
import requests
url = "https://public.tableau.com/app/sample-data/mobile_os_usage.csv"
response = requests.get(url)
csv_text = response.text
target_path ="/Volumes/workspace/default/usage_metrics/mobile_os_usage.csv"
dbutils.fs.put(target_path, csv_text, overwrite=True)
print("Data successfully written to:", target_path)
