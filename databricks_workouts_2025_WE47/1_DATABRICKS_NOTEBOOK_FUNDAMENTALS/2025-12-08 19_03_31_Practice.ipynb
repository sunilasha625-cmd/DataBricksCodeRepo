# %%
# %fs
ls "dbfs:///Volumes/workspace/default/mymanagedtable"

# %%
dbutils.fs.rm("/Volumes/workspace/default/vol/employees.csv")

# %%
# %sql
CREATE TABLE IF NOT EXISTS default.cities1 (
  id INT,
  city STRING
);

INSERT INTO default.cities1 VALUES
  (1, 'Nagpur'),
  (2, 'Bengaluru');

SELECT * FROM default.cities1;

# %%
# %python
spark.sql("select * from cities1").explain(True)

# %%
# %sql
show create table cities1;

# %%
# %sql
select * from cities1

# %%
from pyspark.sql.session import SparkSession
print(spark)
spark1=SparkSession.builder.appName("Spark DataFrame").getOrCreate()
print(spark1)
df1=spark1.read.csv("/Volumes/workspace/default/mymanagedtable/employees.csv")
display(df1)

# %%
df1.where("_c1='Sunil'").write.saveAsTable("default.Suniltable")

# %%
type(df1)

# %%
spark.read.table("Suniltable").show()

# %%
aspirants_list=['Jeeva','Bharathi','Vaanmathy','Nag']
for i in aspirants_list:
  print(i)

# %% [markdown]
# Click here for [Sunil GIT](https://github.com/sunilasha625-cmd/DataBricksCodeRepo)

# %% [markdown]
# ![](/Volumes/workspace/default/mymanagedtable/1000156310.jpg)

# %% [markdown]
# <a href="$./4_child_notebook">Link to notebook in same folder as current notebook</a>
